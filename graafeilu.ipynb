# %%
from graafi import *

# %%
IMAGES={
    "Kansallinen JORY":"LOGOS/AIFNSG.jpg",
    "Helsinki JORY":"LOGOS/helsinki.jpg",
    "Oulu JORY":"LOGOS/oulu.jpg",
    "Tampere JORY":"LOGOS/tampere.jpg",
    "Turku JORY":"LOGOS/turku.jpg",
    "Jyvaskyla JORY":"LOGOS/jyvaskyla.jpg",
    "Operations":"LOGOS/AIFOPS.jpg",
    "Growth Mill":"LOGOS/AIFGM.jpg",
    "Funding Services":"LOGOS/AIFFS.jpg",
    "Ecosystems":"LOGOS/AIFECO.jpg",
    "Shared Assets":"LOGOS/AIFSRE.jpg",
    "VTT":"LOGOS/vtt.jpg",
    "OY":"LOGOS/oulunyliopisto.jpg",
    "OAMK":"LOGOS/OAMK.jpg",
    #"BO":None,
    "JYU":"LOGOS/jyvaskylayo.jpg",
    "TTY":"LOGOS/tut.jpg",
    "AA":"LOGOS/AA.jpg",
    "UTU":"LOGOS/turunyo.jpg",
    "TAMK":"LOGOS/turkuamk.jpg",
    "Novia":"LOGOS/Novia.jpg",
    "HY":"LOGOS/helsinginyo.jpg",
    "BF":"LOGOS/BF.jpg",
    "SuperIoT":"LOGOS/SuperIoT.jpg",
    "AnalyticsPlus":"LOGOS/Analyticsplus.jpg",
    "ArcticDroneLabs":"LOGOS/ArcticDrone.jpg",
    "Gaming":"LOGOS/Gaming.jpg",
    "Water":"LOGOS/Water.jpg",
    "Printocent":"LOGOS/printocent.jpg"

}

KEYWDS={
    "Kansallinen JORY":["BF","Operations","Helsinki","Oulu","Tampere","Turku","Jyvaskyla"],
    "Helsinki JORY":["Helsinki","HY"],
    "Oulu JORY":["Oulu","VTTO","OY","OAMK","BO"],
    "Tampere JORY":["Tampere","TTY","VTTT"],
    "Turku JORY":["Turku","UTU","AA","TAMK","Novia"],
    "Jyvaskyla JORY":["Jyvaskyla","JYU","VTTJ"],
    "Operations":["Operations","GM","FS","ECOS","SRE"],
    "Growth Mill":["GM"],
    "Funding Services":["FS"],
    "Ecosystems":["ECOS","SIOT","APLUS","ADRONE","Water","PRIN","GAME"],
    "Shared Assets":["SRE"],
    "VTT":["VTT","VTTT","VTTO","VTTJ"],
    "OY":["OY"],
    "OAMK":["OAMK"],
    #"BO":["BO"],
    "JYU":["JYU"],
    "TTY":["TTY"],
    "AA":["AA"],
    "UTU":["UTU"],
    "TAMK":["TAMK"],
    "Novia":["Novia"],
    "HY":["HY"],
    "BF":["BF"],
    "SuperIoT":["SIOT"],
    "AnalyticsPlus":["APLUS"],
    "ArcticDroneLabs":["ADRONE"],
    "Gaming":["GAME"],
    "Water":["Water"],
    "Printocent":["PRIN"]

}

ALTKEYWDS={
    "Kansallinen JORY":["BF","Operations","Helsinki","Oulu","Tampere","Turku","Jyvaskyla"],
    "Helsinki JORY":["Helsinki","HY"],
    "Oulu JORY":["Oulu","VTTO","OY","OAMK","BO"],
    "Tampere JORY":["Tampere","TTY","VTTT"],
    "Turku JORY":["Turku","UTU","AA","TAMK","Novia"],
    "Jyvaskyla JORY":["Jyvaskyla","JYU","VTTJ"],
    "Operations":["Operations","GM","FS","ECOS","SRE"],
    "Growth Mill":["GM","Helsinki","Oulu","Tampere","Turku","Jyvaskyla"],
    "Funding Services":["FS","Helsinki","Oulu","Tampere","Turku","Jyvaskyla"],
    "Ecosystems":["ECOS","SIOT","APLUS","ADRONE","Water","PRIN","GAME","Helsinki","Oulu","Tampere","Turku","Jyvaskyla"],
    "Shared Assets":["SRE","Helsinki","Oulu","Tampere","Turku","Jyvaskyla"],
    "VTT":["VTT","VTTT","VTTO","VTTJ"],
    "OY":["OY"],
    "OAMK":["OAMK"],
    #"BO":["BO"],
    "JYU":["JYU"],
    "TTY":["TTY"],
    "AA":["AA"],
    "UTU":["UTU"],
    "TAMK":["TAMK"],
    "Novia":["Novia"],
    "HY":["HY"],
    "BF":["BF"],
    "SuperIoT":["SIOT","Oulu","Helsinki","Turku","Jyvaskyla"],
    "AnalyticsPlus":["APLUS","Oulu","Helsinki","Jyvaskyla"],
    "ArcticDroneLabs":["ADRONE","Oulu","Helsinki","Turku","Jyvaskyla"],
    "Gaming":["GAME","Oulu","Helsinki","Turku"],
    "Water":["Water","Oulu","Tampere","Jyvaskyla"],
    "Printocent":["PRIN","Oulu"]

}

# %%
IMAGES={
    "Kansallinen JORY":None,
    "Helsinki JORY":None,
    "Oulu JORY":None,
    "Tampere JORY":None,
    "Turku JORY":None,
    "Jyvaskyla JORY":None,
    "Operations":None,
    "Growth Mill":None,
    "Funding Services":None,
    "Ecosystems":None,
    "Shared Assets":None,
    "VTT":None,
    "OY":None,
    "OAMK":None,
    "BO":None,
    "JYU":None,
    "TTY":None,
    "AA":None,
    "UTU":None,
    "TAMK":None,
    "Novia":None,
    "HY":None,
    "BF":None,
    "SuperIoT":None,
    "AnalyticsPlus":None,
    "ArcticDroneLabs":None,
    "Gaming":None,
    "Water":None,
    "Printocent":None

}

KEYWDS={
    "Kansallinen JORY":["BF","Operations","Helsinki","Oulu","Tampere","Turku","Jyvaskyla"],
    "Helsinki JORY":["Helsinki","HY"],
    "Oulu JORY":["Oulu","VTTO","OY","OAMK","BO"],
    "Tampere JORY":["Tampere","TTY","VTTT"],
    "Turku JORY":["Turku","UTU","AA","TAMK","Novia"],
    "Jyvaskyla JORY":["Jyvaskyla","JYU","VTTJ"],
    "Operations":["Operations","GM","FS","ECOS","SRE"],
    "Growth Mill":["GM"],
    "Funding Services":["FS"],
    "Ecosystems":["ECOS","SIOT","APLUS","ADRONE","Water","PRIN","GAME"],
    "Shared Assets":["SRE"],
    "VTT":["VTT","VTTT","VTTO","VTTJ"],
    "OY":["OY"],
    "OAMK":["OAMK"],
    "BO":["BO"],
    "JYU":["JYU"],
    "TTY":["TTY"],
    "AA":["AA"],
    "UTU":["UTU"],
    "TAMK":["TAMK"],
    "Novia":["Novia"],
    "HY":["HY"],
    "BF":["BF"],
    "SuperIoT":["SIOT"],
    "AnalyticsPlus":["APLUS"],
    "ArcticDroneLabs":["ADRONE"],
    "Gaming":["GAME"],
    "Water":["Water"],
    "Printocent":["PRIN"]

}

ALTKEYWDS=KEYWDS

# %%
IMAGES={
    "kuu":"kuu.jpg",
    "konna":"konna.jpg",
    "silma":"SILMA.jpg",
    "janne":"Janne.jpg",
    "kerpsu":"kerpsu.jpg",
    "mokki":"mokki.jpg",
    "sorsa":"sorsa.jpg"
}

KEYWDS={
    "kuu":["pimea","maisema","kuu","rakennus"],
    "konna":["elain","silma","luonto","konna"],
    "silma":["silma","maisema","ihminen"],
    "janne":["silma","ihminen"],
    "kerpsu":["elain"],
    "mokki":["rakennus","luonto"],
    "sorsa":["elain","luonto"]
}

ALTKEYWDS={
    "kuu":["musta","sininen","oranssi"],
    "konna":["keltainen"],
    "silma":["sininen","harmaa","vihrea","valkoinen"],
    "janne":["sininen","valkoinen"],
    "kerpsu":["musta"],
    "mokki":["harmaa","sininen","vihrea"],
    "sorsa":["keltainen","sininen","punainen","vihrea"]
}

# %%
IMAGES={
    "Sasu Tarkoma":"LOGOS/AIFNSG.jpg",
    "Ville Leppanen":"LOGOS/AIFNSG.jpg",
    "Kari Koskinen":"LOGOS/AIFNSG.jpg",
    "Pasi Tyrvainen":"LOGOS/AIFNSG.jpg",
    "Arto Maaninen":"LOGOS/AIFNSG.jpg",
    "Mikko Merimaa":"LOGOS/AIFRSG.jpg",
    "Janne Mustonen":"LOGOS/AIFNSG.jpg",
    "Karri Mikkonen":"LOGOS/AIFNSG.jpg",
    "Oula Valipakka":"LOGOS/AIFNSG.jpg",
    "Tanja Oksa":"LOGOS/AIFNSG.jpg",
    "Mika Klemettinen":"LOGOS/AIFNSG.jpg",
    "Arto Pussinen":"LOGOS/AIFNSG.jpg",
    "Harri Kopola":"LOGOS/AIFNSG.jpg",
    
    "Tommi Mikkonen":"LOGOS/AIFRSG.jpg",
    "Johan Lilius":"LOGOS/AIFRSG.jpg",
    "Pauli Kuosmanen":"LOGOS/AIFRSG.jpg",
    "Petri Jetsu":"LOGOS/AIFRSG.jpg",
    "Jukka Riekki":"LOGOS/AIFRSG.jpg",
    "Jussi Paakkari":"LOGOS/AIFNSG.jpg",
    "Juha Ala-Mursula":"LOGOS/AIFRSG.jpg",
    "Timo Antikainen":"LOGOS/AIFRSG.jpg",

    "Jaakko Sauvola":"LOGOS/AIFOPS.jpg",
    "Paavo Kosonen":"LOGOS/AIFGM.jpg",
    "NN":"LOGOS/AIFSRE.jpg",
    "Marko Jurvansuu":"LOGOS/AIFECO.jpg",
    "Matti Kinnunen":"LOGOS/AIFFS.jpg"


}

KEYWDS={
    "Sasu Tarkoma":["Helsinki","KJORYJasen"],
    "Ville Leppanen":["Turku","KJORYJasen"],
    "Kari Koskinen":["Tampere","KJORYJasen"],
    "Pasi Tyrvainen":["Jyvaskyla","KJORYJasen","PJ"],
    "Arto Maaninen":["Oulu","KJORYJasen","PJ"],
    "Mikko Merimaa":["VTT","Helsinki"],
    "Janne Mustonen":["Oulu","KJORYJasen"],
    "Karri Mikkonen":["Turku","KJORYJasen"],
    "Oula Valipakka":["Tampere","KJORYJasen"],
    "Tanja Oksa":["Jyvaskyla","KJORYJasen"],
    "Mika Klemettinen":["BF","Helsinki","KJORYJasen"],
    "Arto Pussinen":["BF","Helsinki","KJORYJasen"],
    "Harri Kopola":["KJORYJasen"],
    
    "Tommi Mikkonen":["Helsinki"],
    "Johan Lilius":["Turku"],
    "Pauli Kuosmanen":["Tampere"],
    "Petri Jetsu":["VTT","Jyvaskyla"],
    "Jukka Riekki":["Oulu"],
    "Jussi Paakkari":["VTT","Oulu","KJORYJasen"],
    "Juha Ala-Mursula":["Oulu"],
    "Timo Antikainen":["Tampere"],

    "Jaakko Sauvola":["Oulu","Operations"],
    "Paavo Kosonen":["Operations","GM","Turku"],
    "NN":["Operations","SRE","Tampere"],
    "Marko Jurvansuu":["Operations","Ecosyst","Oulu"],
    "Matti Kinnunen":["Operations","FS","Oulu"]


}

ALTKEYWDS={
    "Sasu Tarkoma":["Helsinki"],
    "Ville Leppanen":["Turku"],
    "Kari Koskinen":["Tampere"],
    "Pasi Tyrvainen":["Jyvaskyla"],
    "Arto Maaninen":["Oulu","PJ"],
    "Mikko Merimaa":["VTT","Helsinki"],
    "Janne Mustonen":["Oulu"],
    "Karri Mikkonen":["Turku"],
    "Oula Valipakka":["Tampere"],
    "Tanja Oksa":["Jyvaskyla"],
    "Mika Klemettinen":["BF","Helsinki"],
    "Arto Pussinen":["BF","Helsinki"],
    "Harri Kopola":["Oulu"],
    
    "Tommi Mikkonen":["Helsinki"],
    "Johan Lilius":["Turku"],
    "Pauli Kuosmanen":["Tampere"],
    "Petri Jetsu":["VTT","Jyvaskyla"],
    "Jukka Riekki":["Oulu"],
    "Jussi Paakkari":["VTT","Oulu"],
    "Juha Ala-Mursula":["Oulu"],
    "Timo Antikainen":["Tampere"],

    "Jaakko Sauvola":["Oulu"],
    "Paavo Kosonen":["Turku"],
    "NN":["Tampere","VTT"],
    "Marko Jurvansuu":["Oulu"],
    "Matti Kinnunen":["Oulu"]
}

ALTKEYWDS2={
    "Sasu Tarkoma":["KJORYJasen"],
    "Ville Leppanen":["KJORYJasen"],
    "Kari Koskinen":["KJORYJasen"],
    "Pasi Tyrvainen":["PJ"],
    "Arto Maaninen":["PJ"],
    "Mikko Merimaa":["Varajasen"],
    "Janne Mustonen":["KJORYJasen"],
    "Karri Mikkonen":["KJORYJasen"],
    "Oula Valipakka":["KJORYJasen"],
    "Tanja Oksa":["KJORYJasen"],
    "Mika Klemettinen":["KJORYJasen"],
    "Arto Pussinen":["KJORYJasen"],
    "Harri Kopola":["KJORYJasen"],
    
    "Tommi Mikkonen":["Varajasen"],
    "Johan Lilius":["Varajasen"],
    "Pauli Kuosmanen":["Varajasen"],
    "Petri Jetsu":["Varajasen"],
    "Jukka Riekki":["Varajasen"],
    "Jussi Paakkari":["KJORYJasen"],
    "Juha Ala-Mursula":["Varajasen"],
    "Timo Antikainen":["Varajasen"],

    "Jaakko Sauvola":["Operations"],
    "Paavo Kosonen":["Operations"],
    "NN":["Operations"],
    "Marko Jurvansuu":["Operations"],
    "Matti Kinnunen":["Operations"]


}

# %%
GRAAFI={
    "Nodes":{
        "kuu":{"image":"kuu.jpg"},
        "konna":{"image":"konna.jpg"},
        "silma":{"image":"SILMA.jpg"}
            },
    "Edges":[["kuu","konna"],["kuu","silma"],["silma","konna"]]
    }

# %%
rx=800
ry=600

GRAAFI={"Nodes":{},"Edges":[]}
DICTfromKEYWDS(KEYWDS, GRAAFI)
IMAGEStoDICT(IMAGES, GRAAFI)
GR=GRfromDICT(GRAAFI,rx,ry)
GR.bgcolor=(45,11,11)
writer = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"MJPG"), 30,(800,600))


cv2.startWindowThread()
cv2.namedWindow('Graafi')
cv2.setMouseCallback('Graafi',GR.mouseaction)
while True:
    GR.MoveAll(sc=0.3)
    img = GR.DrawGraph2(rajat=False, edges=True,labels=False, nodes =True, elabels=False, labelmap=False,logos=True)
    #GR.DrawLabelMap(img,resolution=10)
    writer.write(img)
    cv2.imshow("Graafi",img)
    inp= cv2.waitKey(1)
    if inp==27:
        break
GR.ResetNodeSizes()
edg2=ALTEdgesfromKEYWDS(ALTKEYWDS,GRAAFI)
edg1=GR.edges
GR.edges=edg2

while True:
    GR.MoveAll(sc=0.3)
    img = GR.DrawGraph2(rajat=False, edges=True,labels=False, nodes =True, elabels=False, labelmap=True,logos=True)
    #GR.DrawLabelMap(img,resolution=10)
    writer.write(img)
    cv2.imshow("Graafi",img)
    inp= cv2.waitKey(1)
    if inp==27:
        break

while True:
    GR.MoveAll(sc=0.3)
    img = GR.DrawGraph2(rajat=False, edges=True,labels=True, nodes =True, elabels=False, labelmap=True,logos=True)
    #GR.DrawLabelMap(img,resolution=10)
    writer.write(img)
    cv2.imshow("Graafi",img)
    inp= cv2.waitKey(1)
    if inp==27:
        break
GR.ResetNodeSizes()
edg3=ALTEdgesfromKEYWDS(ALTKEYWDS2,GRAAFI)
GR.edges=edg3
while True:
    GR.MoveAll(sc=0.3)
    img = GR.DrawGraph2(rajat=False, edges=True,labels=False, nodes =True, elabels=False, labelmap=True,logos=False)
    #GR.DrawLabelMap(img,resolution=10)
    writer.write(img)
    cv2.imshow("Graafi",img)
    inp= cv2.waitKey(1)
    if inp==27:
        break
while True:
    GR.MoveAll(sc=0.3)
    img = GR.DrawGraph2(rajat=False, edges=True,labels=True, nodes =True, elabels=False, labelmap=True,logos=False)
    #GR.DrawLabelMap(img,resolution=10)
    writer.write(img)
    cv2.imshow("Graafi",img)
    inp= cv2.waitKey(1)
    if inp==27:
        break
GR.ResetNodeSizes()
edg1=ALTEdgesfromKEYWDS(KEYWDS,GRAAFI)
GR.edges=edg1
while True:
    GR.MoveAll(sc=0.3)
    img = GR.DrawGraph2(rajat=False, edges=True,labels=True, nodes =True, elabels=False, labelmap=False,logos=False)
    #GR.DrawLabelMap(img,resolution=10)
    writer.write(img)
    cv2.imshow("Graafi",img)
    inp= cv2.waitKey(1)
    if inp==27:
        break

        
#while True:
#    GR.MoveAll(sc=.3)
#    img = GR.DrawGraph2(rajat=True, edges=False,labels=False,nodes =False)
#    writer.write(img)
#    cv2.imshow("Graafi",img)
#    inp= cv2.waitKey(1)
#    if inp==27:
#        break

writer.release()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-46c730b89363> in <module>()
#      47         break
#      48 GR.ResetNodeSizes()
# ---> 49 edg3=ALTEdgesfromKEYWDS(ALTKEYWDS2,GRAAFI)
#      50 GR.edges=edg3
#      51 while True:
#
# ~/python/graafit/graafi.py in ALTEdgesfromKEYWDS(KEYWDS, GRAAFI)
#     869     edges=[]
#     870     for e in GRF["Edges"]:
# --> 871         n1=GRAAFI["Nodes"][e[0]]["node"]
#     872         n2=GRAAFI["Nodes"][e[1]]["node"]
#     873         ed=edge(n1,n2)
#
# KeyError: 'Sasu Tarkoma'

# %%
writer.release()

# %%
def IMAGEStoDICT(IMAGES, GRAAFI):
    NodeNames=list(IMAGES.keys())
    for nn in NodeNames:
        GRAAFI["Nodes"].update({nn:{"image":IMAGES[nn]}})
    return GRAAFI

def DICTfromKEYWDS(KEYWDS, GRAAFI):
    NodeNames=list(KEYWDS.keys())
    i=0
    for nn in NodeNames:
        GRAAFI["Nodes"].update({nn:{"Keywords":KEYWDS[nn]}})
    for nn in NodeNames[:-1]:
        i+=1
        for nnn in NodeNames[i:]:
            for kw in KEYWDS[nn]:
                for kww in KEYWDS[nnn]:
                    if kw == kww:
                        GRAAFI["Edges"].append([nn,nnn,kw])
    return GRAAFI

def GRfromDICT(GRAAFI,rx,ry):
    nodes=[]
    NodeNames=list(GRAAFI["Nodes"].keys())
    for nn in NodeNames:
        n=node(np.random.random()*rx,np.random.random()*ry)
        n.label = nn
        n.image=cv2.imread(GRAAFI["Nodes"][nn]["image"])
        #n.color=(60,30,0)
        #n.color=(222,222,222)
        col=np.random.randint(255,dtype=int)
        n.color=(col,col,col)
        #n.color=(np.random.randint(255,dtype=int),np.random.randint(255,dtype=int),np.random.randint(255,dtype=int))
        GRAAFI["Nodes"][nn].update({"node":n})
        nodes.append(n)
    edges=[]
    for e in GRAAFI["Edges"]:
        n1=GRAAFI["Nodes"][e[0]]["node"]
        n2=GRAAFI["Nodes"][e[1]]["node"]     
        ed=edge(n1,n2)
        if len(e)>2: ed.label =e[2]
        edges.append(ed)
        n1.size=n1.size+5.0
        n2.size=n2.size+5.0

    GR=graph(nodes,edges)
    GR.imgsize=np.array([ry,rx,3])
    return GR

def ALTEdgesfromKEYWDS(KEYWDS,GRAAFI):
    NodeNames=list(KEYWDS.keys())
    i=0
    #for nn in NodeNames:
    #    GRAAFI["Nodes"].update({nn:{"Keywords":KEYWDS[nn]}})
    GRF={"Edges":[]}
    for nn in NodeNames[:-1]:
        i+=1
        for nnn in NodeNames[i:]:
            for kw in KEYWDS[nn]:
                for kww in KEYWDS[nnn]:
                    if kw == kww:
                        GRF["Edges"].append([nn,nnn,kw])

    edges=[]
    for e in GRF["Edges"]:
        n1=GRAAFI["Nodes"][e[0]]["node"]
        n2=GRAAFI["Nodes"][e[1]]["node"]     
        ed=edge(n1,n2)
        if len(e)>2: ed.label =e[2]
        edges.append(ed)
        n1.size=n1.size+5.0
        n2.size=n2.size+5.0
    return edges

# %%
l=[[ [] for _ in range(10)] for _ in range(10)]
l[1][2].append("kissa")
l=["k","l","l","k","k","l","l"]
max(l, key=l.count)
h={"kissa":1, "koira":3}
"heppa" in h

# %%
resolution =10
BB=GR.BoundingBoxSet()
mappxx=(BB[1]-BB[0])/resolution
mappxy=(BB[3]-BB[2])/resolution
bx=BB[0]
by=BB[2]
me =[[ [] for _ in range(resolution)] for _ in range(resolution)]
i = int((GR.nodes[9].x-bx)/mappxx)
j = int((GR.nodes[9].y-by)/mappxy)
print(i,j)

# %%
dir(cv2)

# %%
nnodes= 22
nedges = 60

rx=800
ry=600
#rsz=20

kuu=cv2.imread("kuu.jpg")
konna=cv2.imread("konna.jpg")

nodes =[]
for i in range(nnodes):
    n=node(np.random.random()*rx,np.random.random()*ry)
    #n.color=(60,30,0)
    #n.color=(255,255,255)
    n.color=(np.random.randint(255,dtype=int),np.random.randint(255,dtype=int),np.random.randint(255,dtype=int))
    #if np.random.random()>0.5: 
    #    n.image=kuu
    #else:
    #    n.image=konna
    nodes.append(n)
    
edges=[]
ns=nodes.copy()
for i in range(nedges):  
    shuffle(ns)
    shuffle(nodes)
    edges.append(edge(ns[0],nodes[0]))
edges2=[]
for i in range(nedges):  
    shuffle(ns)
    shuffle(nodes)
    edges2.append(edge(ns[0],nodes[0]))

GR=graph(nodes,edges)
GR.imgsize=np.array([ry,rx,3])

writer = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"MJPG"), 30,(rx,ry))
cv2.startWindowThread()
cv2.namedWindow('Graafi')
cv2.setMouseCallback('Graafi',GR.mouseaction)

GR.edges=edges

while True:
    GR.MoveAll()
    img = GR.DrawGraph2(rajat=True, edges=False)
    writer.write(img)
    cv2.imshow("Graafi",img)

    inp= cv2.waitKey(1)
    if inp==27:
        break
        
GR.edges=edges2

while True:
    GR.MoveAll()
    img = GR.DrawGraph2(rajat=True, edges=False)
    writer.write(img)
    cv2.imshow("Graafi",img)

    inp= cv2.waitKey(1)
    if inp==27:
        break
GR.edges=edges

while True:
    GR.MoveAll()
    img = GR.DrawGraph2(rajat=True, edges=False)
    writer.write(img)
    cv2.imshow("Graafi",img)

    inp= cv2.waitKey(1)
    if inp==27:
        break
GR.edges=edges2

while True:
    GR.MoveAll(sc=.1)
    img = GR.DrawGraph2(rajat=True, edges=False)
    writer.write(img)
    cv2.imshow("Graafi",img)

    inp= cv2.waitKey(1)
    if inp==27:
        break

writer.release()

# %%
writer = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"MJPG"), 30,(640,480))

writer.write()

writer.release()

# %%
import pylab as pl

def sigmoid(z):
    return 1.0/(1.0+np.exp(-z))

def PotentialSize(ro, size=10, repulsion = True):

    towards=1.0
    if repulsion: towards = 0

    #nearfield
    rnf=size
    rmin=10
    rnf=max(rmin,rnf)
    rnsc=5/rnf
    pnf = -rnf/8

    #midfield
    rmf=(ro/rnf-0.3)
    pmf = -1/(.1+(rmf*rmf))+7*towards

    #farfield
    rff=6*rnf
    rfsc=20/rff
    pff = 0.5+6.5*towards

    #transition: near-fied - mid-field
    r=(ro-rnf)*rnsc
    sgm_nf=sigmoid(r)
    pnmf= (1-sgm_nf)*pnf + sgm_nf*pmf

    #transition: ... - far-field
    r=(ro-rff)*rfsc
    sgm_ff=sigmoid(r)
    p=(1-sgm_ff)*pnmf + sgm_ff*pff

    return p

# %%
ro = np.linspace(0,500,100) # 100 linearly spaced numbers

p= PotentialSize(ro, size=60, repulsion = True)
pp= PotentialSize(ro, size=60, repulsion = False)
p2=[]
for i in range(len(ro)):
    (px,py)=potential(ro[i],0, mode="rep", scale=1.0)
    p2.append(px)
pr=-1*np.array(p2)
p2=[]
for i in range(len(ro)):
    (px,py)=potential(ro[i],0, mode="normal", scale=1.0)
    p2.append(px)
pn=-1*np.array(p2)

#pl.plot(ro,sgm_nf)
#pl.plot(ro,sgm_ff)

#pl.plot(ro,pnmf)
pl.plot(ro,p,"y")
pl.plot(ro,pp,"b")
pl.plot(ro,pn,"g")
pl.plot(ro,pr,"r")
pl.grid(True, axis='y', linewidth=1, color='gray', linestyle='--')
pl.show()

# %%
import pylab
import numpy

x = numpy.linspace(-15,15,100) # 100 linearly spaced numbers
y = numpy.sin(x)/x # computing the values of sin(x)/x

# compose plot
pylab.plot(x,y) # sin(x)/x
pylab.plot(x,y,'co') # same function with cyan dots
pylab.plot(x,2*y,x,3*y) # 2*sin(x)/x and 3*sin(x)/x
pylab.show() # show the plot

# %%
cv2.destroyWindow
